# %%
# !apt-get install python3.11
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.11 1
# !sudo update-alternatives --set python3 /usr/bin/python3.11

# !python --version
# !update-alternatives --display python3

# %%
# !apt-get install python3-pip
# !python -m pip install --upgrade pip --user

# %%
# !sudo apt-get update
# !sudo apt-get install python3.11-dev -y

# %%
# !export PIP_EXTRA_INDEX_URL="https://pypi.ngc.nvidia.com https://download.pytorch.org/whl/cu121"

# %%
# %cd /kaggle/working
# !git clone https://github.com/wlfeng0509/Fast-SAM3D.git
# %cd Fast-SAM3D

# %%
# !pip install -e '.[dev]'

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# %cd /kaggle/working
# Clone the utils3d repository
# !git clone https://github.com/EasternJournalist/utils3d.git
# Navigate to the repository
# %cd utils3d
# Checkout the specific commit
# !git checkout 3913c65d81e05e47b9f367250cf8c0f7462a0900
# Install the package (NOT in editable mode)
# !pip install .

# %%
# %cd /kaggle/working
# !git clone https://github.com/EasternJournalist/MoGe.git
# %cd MoGe

# Comment dòng utils3d trong requirements.txt
# !sed -i 's|^git+https://github.com/EasternJournalist/utils3d.git|# &|' requirements.txt
# Sửa tên dependency trong pyproject.toml
# !sed -i 's|"utils3d @ git+https://github.com/EasternJournalist/utils3d.git@3fab839f0be9931dac7c8488eb0e1600c236e183"|"utils3d"|' pyproject.toml

# !pip install .

# %%
# %cd /kaggle/working/utils3d

# Tạo một liên kết (symbolic link) để khi gọi .pt nó sẽ trỏ vào .torch
# !ln -s torch utils3d/pt

# Cài đặt lại để cập nhật thay đổi vào hệ thống
# !pip install --force-reinstall .

# %%
# !pip install wheel setuptools
# !pip install --upgrade setuptools pip wheel

# %%
# !pip install hatchling hatch-requirements-txt

# %%
# %cd /kaggle/working
# !git clone https://github.com/nerfstudio-project/gsplat.git

# %%
# %cd /kaggle/working/gsplat
# !git submodule update --init --recursive
# !sudo apt-get update && sudo apt-get install libglm-dev -y

# !export CUDA_HOME=/usr/local/cuda; \
#  export TORCH_CUDA_ARCH_LIST="7.5"; \
#  export DEB_PYTHON_INSTALL_LAYOUT=deb; \
#  pip wheel . --no-build-isolation -w /kaggle/working/my_wheels

# !pip install /kaggle/input/datasets/lhuyton/gsplat-wheel/gsplat-1.5.3-cp311-cp311-linux_x86_64.whl

# %%
# !pip install fvcore iopath

# %%
# %cd /kaggle/working
# !git clone https://github.com/facebookresearch/pytorch3d.git
# %cd pytorch3d

# %%
# %cd /kaggle/working/pytorch3d

# # # Chạy lệnh cài đặt tổng hợp
# !export FORCE_CUDA=1; \
#  export TORCH_CUDA_ARCH_LIST="7.5"; \
#  export DEB_PYTHON_INSTALL_LAYOUT=deb; \
#  pip wheel . --no-build-isolation -v -w /kaggle/working/my_wheels2

# !pip install /kaggle/input/datasets/lhuyton/pytorch-wheel/pytorch3d-0.7.9-cp311-cp311-linux_x86_64.whl

# %%
# Configure Kaolin download link
# !export PIP_FIND_LINKS="https://nvidia-kaolin.s3.us-east-2.amazonaws.com/torch-2.5.1_cu121.html"

# %%
# !pip install setuptools==69.5.1

# %%
# !pip install warp-lang ipython

# %%
# !pip install seaborn==0.13.2
# !pip install gradio==5.49.0
# !pip install "numpy>=2.0.0,<2.3.0"

# %%
# !pip install kaolin==0.17.0 -f https://nvidia-kaolin.s3.us-east-2.amazonaws.com/torch-2.4.0_cu121.html --ignore-installed

# %%
# !MAX_JOBS=4 pip install flash_attn==2.8.3 --no-build-isolation -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
# !pip install --upgrade huggingface_hub

# %%
from huggingface_hub import login
login(token="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")

# %%
# !pip install omegaconf loguru timm plotly open3d optree astor lightning spconv xatlas pyvista pymeshfix igraph easydict imageio

# %%
# !pip install hydra-core --upgrade

# %%
# !pip install "numpy<2.0" "scipy>=1.11"

# %%
import os
from huggingface_hub import snapshot_download

# Đường dẫn mà Fast-SAM3D đang tìm kiếm
checkpoint_dir = "/kaggle/working/Fast-SAM3D/checkpoints/moge-vitl"
os.makedirs(checkpoint_dir, exist_ok=True)

# Tải từ repo chính xác
try:
    snapshot_download(
        repo_id="Ruicheng/moge-vitl", 
        local_dir=checkpoint_dir
    )
    print(f"✅ Thành công! File đã nằm tại: {checkpoint_dir}")
except Exception as e:
    print(f"❌ Vẫn lỗi: {e}")

# %%
# !grep "pretrained_model_name_or_path" hf/pipeline.yaml

# %%
# Chuyển vào thư mục checkpoints bên trong notebook
# %cd /kaggle/working/Fast-SAM3D/notebook/checkpoints

# # Lệnh này sẽ tìm tất cả các file .yaml và thay thế đường dẫn của tác giả bằng đường dẫn Kaggle của bạn
# !find . -type f -name "*.yaml" -exec sed -i 's|/data3/wmq/Fast-sam3d-objects/checkpoints/|/kaggle/working/Fast-SAM3D/notebook/checkpoints/|g' {} +

# Kiểm tra lại xem dòng đó đã được sửa chưa
# !grep "pretrained_model_name_or_path" /kaggle/input/models/lhuyton/checkpoints/other/default/4/pipeline.yaml

# %%
import os

# 1. Định nghĩa đường dẫn nguồn (từ Input) và đích (trong Working)
input_path = "/kaggle/input/models/lhuyton/checkpoints/other/default/4"
target_dir = "/kaggle/working/Fast-SAM3D/notebook/checkpoints/hf"

# 2. Di chuyển vào thư mục làm việc
# %cd /kaggle/working/Fast-SAM3D/notebook

# 3. Xóa thư mục/link cũ nếu có và tạo thư mục cha
# !rm -rf checkpoints/hf
os.makedirs(os.path.dirname(target_dir), exist_ok=True)
os.makedirs(target_dir, exist_ok=True)

# 4. Tạo liên kết ảo cho TOÀN BỘ file từ Input vào thư mục hf
# !ln -sf {input_path}/* {target_dir}/

print(f"✅ Đã liên kết dữ liệu vào: {target_dir}")
# Kiểm tra lại danh sách file đã có trong hf chưa
# !ls {target_dir}

# %%
# Di chuyển ra thư mục gốc của dự án
# %cd /kaggle/working/Fast-SAM3D

# Tìm và thay thế tất cả các chuỗi đường dẫn của tác giả cũ trong toàn bộ code
# !grep -rll "/data3/wmq" . | xargs sed -i "s|/data3/wmq/Fast-sam3d-objects/checkpoints/torch-cache|/kaggle/working/torch-cache|g"

print("✅ Đã dọn dẹp sạch sẽ các đường dẫn trong toàn bộ mã nguồn!")
# %cd /kaggle/working/Fast-SAM3D/notebook
# !grep "TORCH_HOME" infer.py

# %%
import os

# 1. Tạo thư mục cha (dùng -p để tạo cả chuỗi thư mục nếu chưa có)
# !mkdir -p /kaggle/working/torch-cache/hub/

# 2. Di chuyển vào thư mục đó
# %cd /kaggle/working/torch-cache/hub/

# 3. Xóa thư mục cũ nếu lỡ có bản lỗi, sau đó tải bản mới
# !rm -rf facebookresearch_dinov2_main
# !git clone https://github.com/facebookresearch/dinov2.git facebookresearch_dinov2_main

# 4. Kiểm tra xem file hubconf.py đã xuất hiện chưa
if os.path.exists("facebookresearch_dinov2_main/hubconf.py"):
    print("✅ Tuyệt vời! File hubconf.py đã sẵn sàng tại đúng vị trí.")
else:
    print("❌ Lỗi: Vẫn không thấy file. Hãy kiểm tra xem bạn đã bật 'Internet ON' ở bảng bên phải chưa.")

# %%
# 1. Đảm bảo đang ở trong thư mục notebook
# %cd /kaggle/working/Fast-SAM3D/notebook

# 2. Tạo thư mục examples
# !mkdir -p examples

# 3. Kiểm tra xem file ảnh có tồn tại không
import os
if os.path.exists("examples/image.png"):
    print("✅ Đã tìm thấy ảnh tại examples/image.png")
else:
    print("❌ CHƯA CÓ ẢNH! Bạn cần upload ảnh lên Kaggle hoặc copy từ nơi khác vào đây.")

# %%
# !cp /kaggle/input/datasets/lhuyton/blackcar/image.png /kaggle/working/Fast-SAM3D/notebook/examples/image.png
# !cp /kaggle/input/datasets/lhuyton/blackcar/1.png /kaggle/working/Fast-SAM3D/notebook/examples/1.png

# %%
# 1. Gỡ cài đặt bản spconv hiện tại
# !pip uninstall -y spconv

# 2. Cài đặt bản spconv hỗ trợ CUDA 12.x (phổ biến trên Kaggle hiện nay)
# Nếu Kaggle dùng CUDA 12, lệnh sau sẽ tự động chọn bản phù hợp
# !pip install spconv-cu121

# %%
# Thay thế tất cả các lời gọi utils3d.pt thành utils3d.torch trong thư viện MoGe
# !grep -rl "utils3d.pt" /usr/local/lib/python3.11/dist-packages/moge/ | xargs sed -i 's/utils3d.pt/utils3d.torch/g'

print("✅ Đã sửa xong các tham chiếu trong thư viện MoGe")

# %%
import shutil
import os

# Đường dẫn file bạn vừa upload (Hãy kiểm tra lại tên dataset của bạn)
src_path = '/kaggle/input/datasets/lhuyton/pipeline/inference_pipeline.py'

# Đường dẫn file cũ cần thay thế
dest_path = '/kaggle/working/Fast-SAM3D/sam3d_objects/pipeline/inference_pipeline.py'

if os.path.exists(src_path):
    # Sao chép và ghi đè
    shutil.copy(src_path, dest_path)
    print("✅ Đã thay thế file inference_pipeline.py thành công!")
else:
    print("❌ Không tìm thấy file nguồn. Hãy kiểm tra lại tên Dataset trong /kaggle/input")

# %%
import os
import torch
import gc

# 1. Cấu hình môi trường cực đoan
os.environ['CONDA_PREFIX'] = '/opt/conda'
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
os.environ['PYTHONPATH'] = "/kaggle/working/Fast-SAM3D:/kaggle/working/Fast-SAM3D/sam3d_objects"

# 2. Dọn dẹp tuyệt đối
gc.collect()
torch.cuda.empty_cache()

# 3. Chạy Inference với các tham số tiết kiệm
# %cd /kaggle/working/Fast-SAM3D/notebook

# !python infer.py \
#     --image_path examples/image.png \
#     --mask_index 1 \
#     --enable_ss_cache \
#     --enable_slat_carving \
#     --enable_mesh_aggregation

# !python infer.py \
    --image_path examples/image.png \
    --mask_index 1 \
    --output_dir outputs/ \
    --enable_acceleration
